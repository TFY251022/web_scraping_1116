# %% [markdown]
# ### Requests 夾帶 cookie

# %%
import requests
from bs4 import BeautifulSoup as bs

 # PTT Gossiiping (八卦版) 
url = "https://www.ptt.cc/bbs/Gossiping/index.html"

# 首頁網址
prefix = 'https://www.ptt.cc'

# 設定 cookie
my_cookies = {
    "over18": "1"
}

# 用 requests 的 get 方法把網頁抓下來
res = requests.get(url, cookies = my_cookies) 

# 指定 lxml 作為解析器
soup = bs(res.text, "lxml")

# 顯示連結列表
for a in soup.select('div.r-ent > div.title > a'):
    print(a.get_text())
    print(prefix + a['href'])
# Out:
# Re: [問卦] 啤酒(beer)是否算酒(wine)?
# https://www.ptt.cc/bbs/Gossiping/M.1763185764.A.408.html
# Re: [問卦] 館長生意賠錢是給一些豬朋狗友超高薪水
# https://www.ptt.cc/bbs/Gossiping/M.1763185798.A.C25.html
# [問卦] 馬卡真的有效嗎
# https://www.ptt.cc/bbs/Gossiping/M.1763185846.A.B74.html
# [問卦] 陳沂：館長喜歡NTR怎麼不找王子？
# https://www.ptt.cc/bbs/Gossiping/M.1763185916.A.D52.html
# Re: [問卦] 6大環團反對光電環評更嚴格？？？
# https://www.ptt.cc/bbs/Gossiping/M.1763185949.A.F48.html
# Re: [問卦] 有沒有可能是館長自己想看小偉的老二
# https://www.ptt.cc/bbs/Gossiping/M.1763185957.A.387.html
# [公告] 八卦板板規(2025.01.21)
# https://www.ptt.cc/bbs/Gossiping/M.1737398137.A.644.html
# Re: [問卦] 請勿前往光復區，鏟子超人任務艱鉅，病例增。
# https://www.ptt.cc/bbs/Gossiping/M.1759065775.A.9B4.html
# [公告] 【八卦美學獎】梗圖吐槽，共鳴豹紋笑翻！
# https://www.ptt.cc/bbs/Gossiping/M.1761980569.A.84C.html
# [公告] 11/14 八卦踢報十大頭條 11月協尋 置底閒聊
# https://www.ptt.cc/bbs/Gossiping/M.1763077421.A.B5B.html
