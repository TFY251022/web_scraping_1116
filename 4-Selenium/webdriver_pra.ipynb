# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service('./chromedriver-win64/chromedriver.exe')

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome( options=options)
driver.get("https://www.104.com.tw/")

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
# 寫法 1 - 使用 CLASS_NAME
driver.find_element(By.CLASS_NAME, "form-control").send_keys("Python")

# %%
# 寫法 2 - 使用 CSS_SELECTOR 找父層後再找子層
driver.find_element(By.CSS_SELECTOR, ".input-group.input-group--search").find_element(By.TAG_NAME, "input").send_keys("python")

# %%
# 寫法 2 - 使用 CSS_SELECTOR 找父層後再找子層
# 先清空再輸入
cancel_ele = driver.find_element(By.CSS_SELECTOR, ".input-group.input-group--search i").click()
input_ele = driver.find_element(By.CSS_SELECTOR, ".input-group.input-group--search input").send_keys("python")

# %%
# 
cancel_ele = driver.find_element(By.CSS_SELECTOR, ".input-group.input-group--search i")
if cancel_ele:
    try:
        cancel_ele.click()
    except Exception as e:
        print("取消按鈕點擊失敗:", e)
driver.find_element(By.CSS_SELECTOR, ".input-group.input-group--search input").send_keys("python")

# %%
# 寫法 3 - 使用 CSS_SELECTOR 使用屬性精準匹配
driver.find_element(By.CSS_SELECTOR, "input[data-gtm-index='搜尋欄位-搜尋點擊']").send_keys("python")

# %%
# 點擊搜尋按鈕
driver.find_element(By.CSS_SELECTOR, ".col.col-2 button").click()

# %% [markdown]
# ### 查找不同地區的資料

# %%
import time
# 點擊地區選單
driver.find_element(By.CSS_SELECTOR, "button[data-gtm-joblist='搜尋欄位-地區']").click()
time.sleep(2)

# 取得所有區域選項的 value 以提供後續訪問各地區使用

"""
<a class="category-picker-checkbox">
  <span class="category-picker-checkbox-input">
    <input type="checkbox" class="checkbox-input" value="6001001000">
   </span>
  <span class="children">台北市</span>
</a>
"""
area_elements = driver.find_elements(By.CLASS_NAME, ".category-picker-checkbox")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[26], line 3
#       1 import time
#       2 # 點擊地區選單
# ----> 3 driver.find_element(By.CSS_SELECTOR, "button[data-gtm-joblist='搜尋欄位-地區']").click()
#       4 time.sleep(2)
#       6 # 取得所有區域選項的 value 以提供後續訪問各地區使用
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"button[data-gtm-joblist='搜尋欄位-地區']"}
#   (Session info: chrome=142.0.7444.163); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7fe82a235
# 	0x7ff7fe582650
# 	0x7ff7fe3116dd
# 	0x7ff7fe36a27e
# 	0x7ff7fe36a58c
# 	0x7ff7fe3bed77
# 	0x7ff7fe3bbaba
# 	0x7ff7fe35b0ed
# 	0x7ff7fe35bf63
# 	0x7ff7fe855d60
# 	0x7ff7fe84fe8a
# 	0x7ff7fe871005
# 	0x7ff7fe59d73e
# 	0x7ff7fe5a4e3f
# 	0x7ff7fe58b7e4
# 	0x7ff7fe58b99f
# 	0x7ff7fe571908
# 	0x7fffb14d7374
# 	0x7fffb161cc91

# %%
print(area_elements.find_element(By.TAG_NAME, "input").get_attribute("value"))
print(area_elements.find_element(By.CLASS_NAME, "children").text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 #driver.quit()
# ----> 2 print(area_elements.find_element(By.TAG_NAME, "input").get_attribute("value"))
#       3 print(area_elements.find_element(By.CLASS_NAME, "children").text)
#
# AttributeError: 'list' object has no attribute 'find_element'

# %%
driver.quit()

# %%
# 確認抓取到的
district_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # 確認抓取到的
# ----> 2 district_value
#
# NameError: name 'district_value' is not defined

# %%
# 取得台北市的 value 
area = district_value["台北市"]

# 造訪台北市的搜尋結果頁面
driver.get(f"https://www.104.com.tw/jobs/search/?area={area}&jobsource=index_s&keyword=python&mode=s&page=1")

# %%
# 取得所有工作項目元素

# %%
# 取得職缺資訊

# %%
# 開啟新分頁

# %%
# 取得所有分頁的 list

# 切換至新分頁

# %%
# 前往職缺詳細頁面

# %%
# 關閉分頁

# %%
# 關閉分頁後如未切回原分頁，會無法操作
# driver.get(job_url)

# 切回原分頁

# %% [markdown]
# ### 下滑至頁面底部，載入更多職缺

# %%
# 執行下滑至頁面底部
